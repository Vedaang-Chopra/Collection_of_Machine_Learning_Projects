# %% [markdown]
# # Census Income Analysis

# %%
# Import the necessasry libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sc
from collections import Counter

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import f1_score

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
# Load the Census dataset and change column names

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data',
                 names = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','salary_detail'])

# %%
# Display the dataset

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country salary_detail
# 0          2174             0              40   United-States         <=50K
# 1             0             0              13   United-States         <=50K
# 2             0             0              40   United-States         <=50K
# 3             0             0              40   United-States         <=50K
# 4             0             0              40            Cuba         <=50K

# %% [markdown]
# Fetch basic information about the dataset attributes

# %%
# Create data dictionary giving description of columns in the dataset

# %% [markdown]
# Attribute Information:
#
# Details of attribues in data set are described below:
# 1. Age: Describes the age of individuals. Variable Type : Continuous
# 2. Workclass: Describes type of employment of individuals. Variable Type: Categorical
# 3. fnlwgt: Final weight on Current Population Survey. Variable Type :Continuous.
# 4. education: Describes type of education of individuals. Variable Type: Categorical
# 5. education-num: Number of years spent in education. Variable Type: Continuous.
# 6. marital-status: Describes marital status of individuals. Variable Type: Categorical
# 7. occupation: Describes occupation type of individuals. Variable Type: Categorical
# 8. relationship: Describes relationship of individuals to other members. Variable Type: Categorical
# 9. race: Race of the individual.  Variable Type: Categorical
# 10. sex: Gender of the individual. Variable Type: Categorical
# 11. capital-gain: Capital gain details of the individual. Variable Type: Continuous.
# 12. capital-loss: Capital loss details of the individual. Variable Type: Continuous.
# 13. hours-per-week: Hours worked per week. Variable Type: Continuous.
# 14. native-country: Native country of the individual. Variable Type: Categorical
# 15. salary_detail: Target class indicating salary >50K or  <=50K

# %%
categorical_features = list(df.select_dtypes(include=['object']).columns)
print(categorical_features)
numerical_features = list(df.select_dtypes(include=['int64', 'float64']).columns)
print(numerical_features)
# Out:
# ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'salary_detail']
# ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# %%
# Fetch basic information about the dataset attributes

# %%
print('Shape of Entire Dataframe:',df.shape)
# Out:
# Shape of Entire Dataframe: (32561, 15)

# %%
df.info()
df['salary_detail'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary_detail   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
#  <=50K    24720
#  >50K      7841
# Name: salary_detail, dtype: int64

# %%
for i in range (0, df.shape[1]):
    print("Data type of feature/column ", df.columns[i]," is: ",type(df.iloc[1,i]))
# Out:
# Data type of feature/column  age  is:  <class 'numpy.int64'>
# Data type of feature/column  workclass  is:  <class 'str'>
# Data type of feature/column  fnlwgt  is:  <class 'numpy.int64'>
# Data type of feature/column  education  is:  <class 'str'>
# Data type of feature/column  education-num  is:  <class 'numpy.int64'>
# Data type of feature/column  marital-status  is:  <class 'str'>
# Data type of feature/column  occupation  is:  <class 'str'>
# Data type of feature/column  relationship  is:  <class 'str'>
# Data type of feature/column  race  is:  <class 'str'>
# Data type of feature/column  sex  is:  <class 'str'>
# Data type of feature/column  capital-gain  is:  <class 'numpy.int64'>
# Data type of feature/column  capital-loss  is:  <class 'numpy.int64'>
# Data type of feature/column  hours-per-week  is:  <class 'numpy.int64'>
# Data type of feature/column  native-country  is:  <class 'str'>
# Data type of feature/column  salary_detail  is:  <class 'str'>

# %%
# Describe the continuous features of dataset

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Data Cleanup - Check for missing values

# %%
def missing_check(df):
    total = df.isnull().sum().sort_values(ascending=False)   # total number of null values
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)  # percentage of values that are null
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])  # putting the above two together
    return missing_data # return the dataframe
missing_check(df)
# Out:
#                 Total  Percent
# age                 0      0.0
# workclass           0      0.0
# fnlwgt              0      0.0
# education           0      0.0
# education-num       0      0.0
# marital-status      0      0.0
# occupation          0      0.0
# relationship        0      0.0
# race                0      0.0
# sex                 0      0.0
# capital-gain        0      0.0
# capital-loss        0      0.0
# hours-per-week      0      0.0
# native-country      0      0.0
# salary_detail       0      0.0

# %%
# Data Cleanup - Check for duplicate values

# %%
# Data cleanup - Check for missing Values per Column in the dataframe

# %%
for i in df.columns:
  print(pd.DataFrame({'value' : df[i], 'Missing?' : df[i].isnull()}))
# Out:
#        value  Missing?
# 0         39     False
# 1         50     False
# 2         38     False
# 3         53     False
# 4         28     False
# ...      ...       ...
# 32556     27     False
# 32557     40     False
# 32558     58     False
# 32559     22     False
# 32560     52     False
#
# [32561 rows x 2 columns]
#                    value  Missing?
# 0              State-gov     False
# 1       Self-emp-not-inc     False
# 2                Private     False
# 3                Private     False
# 4                Private     False
# ...                  ...       ...
# 32556            Private     False
# 32557            Private     False
# 32558            Private     False
# 32559            Private     False
# 32560       Self-emp-inc     False
#
# [32561 rows x 2 columns]
#         value  Missing?
# 0       77516     False
# 1       83311     False
# 2      215646     False
# 3      234721     False
# 4      338409     False
# ...       ...       ...
# 32556  257302     False
# 32557  154374     False
# 32558  151910     False
# 32559  201490     False
# 32560  287927     False
#
# [32561 rows x 2 columns]
#              value  Missing?
# 0        Bachelors     False
# 1        Bachelors     False
# 2          HS-grad     False
# 3             11th     False
# 4        Bachelors     False
# ...            ...       ...
# 32556   Assoc-acdm     False
# 32557      HS-grad     False
# 32558      HS-grad     False
# 32559      HS-grad     False
# 32560      HS-grad     False
#
# [32561 rows x 2 columns]
#        value  Missing?
# 0         13     False
# 1         13     False
# 2          9     False
# 3          7     False
# 4         13     False
# ...      ...       ...
# 32556     12     False
# 32557      9     False
# 32558      9     False
# 32559      9     False
# 32560      9     False
#
# [32561 rows x 2 columns]
#                      value  Missing?
# 0            Never-married     False
# 1       Married-civ-spouse     False
# 2                 Divorced     False
# 3       Married-civ-spouse     False
# 4       Married-civ-spouse     False
# ...                    ...       ...
# 32556   Married-civ-spouse     False
# 32557   Married-civ-spouse     False
# 32558              Widowed     False
# 32559        Never-married     False
# 32560   Married-civ-spouse     False
#
# [32561 rows x 2 columns]
#                     value  Missing?
# 0            Adm-clerical     False
# 1         Exec-managerial     False
# 2       Handlers-cleaners     False
# 3       Handlers-cleaners     False
# 4          Prof-specialty     False
# ...                   ...       ...
# 32556        Tech-support     False
# 32557   Machine-op-inspct     False
# 32558        Adm-clerical     False
# 32559        Adm-clerical     False
# 32560     Exec-managerial     False
#
# [32561 rows x 2 columns]
#                 value  Missing?
# 0       Not-in-family     False
# 1             Husband     False
# 2       Not-in-family     False
# 3             Husband     False
# 4                Wife     False
# ...               ...       ...
# 32556            Wife     False
# 32557         Husband     False
# 32558       Unmarried     False
# 32559       Own-child     False
# 32560            Wife     False
#
# [32561 rows x 2 columns]
#         value  Missing?
# 0       White     False
# 1       White     False
# 2       White     False
# 3       Black     False
# 4       Black     False
# ...       ...       ...
# 32556   White     False
# 32557   White     False
# 32558   White     False
# 32559   White     False
# 32560   White     False
#
# [32561 rows x 2 columns]
#          value  Missing?
# 0         Male     False
# 1         Male     False
# 2         Male     False
# 3         Male     False
# 4       Female     False
# ...        ...       ...
# 32556   Female     False
# 32557     Male     False
# 32558   Female     False
# 32559     Male     False
# 32560   Female     False
#
# [32561 rows x 2 columns]
#        value  Missing?
# 0       2174     False
# 1          0     False
# 2          0     False
# 3          0     False
# 4          0     False
# ...      ...       ...
# 32556      0     False
# 32557      0     False
# 32558      0     False
# 32559      0     False
# 32560  15024     False
#
# [32561 rows x 2 columns]
#        value  Missing?
# 0          0     False
# 1          0     False
# 2          0     False
# 3          0     False
# 4          0     False
# ...      ...       ...
# 32556      0     False
# 32557      0     False
# 32558      0     False
# 32559      0     False
# 32560      0     False
#
# [32561 rows x 2 columns]
#        value  Missing?
# 0         40     False
# 1         13     False
# 2         40     False
# 3         40     False
# 4         40     False
# ...      ...       ...
# 32556     38     False
# 32557     40     False
# 32558     40     False
# 32559     20     False
# 32560     40     False
#
# [32561 rows x 2 columns]
#                 value  Missing?
# 0       United-States     False
# 1       United-States     False
# 2       United-States     False
# 3       United-States     False
# 4                Cuba     False
# ...               ...       ...
# 32556   United-States     False
# 32557   United-States     False
# 32558   United-States     False
# 32559   United-States     False
# 32560   United-States     False
#
# [32561 rows x 2 columns]
#         value  Missing?
# 0       <=50K     False
# 1       <=50K     False
# 2       <=50K     False
# 3       <=50K     False
# 4       <=50K     False
# ...       ...       ...
# 32556   <=50K     False
# 32557    >50K     False
# 32558   <=50K     False
# 32559   <=50K     False
# 32560    >50K     False
#
# [32561 rows x 2 columns]

# %%
# Removing target variable from dataset duplicate.

# %%
df1 = df.copy()
y=df['salary_detail'].to_numpy()
del df1['salary_detail']
df1
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
# [32561 rows x 14 columns]

# %%
# Univariate Analysis for different categorical and continuous columns

# %%
#df[categorical_features[0]].value_counts().plot.bar()
for i in range(len(categorical_features)):
    print("Feature Name:",categorical_features[i])
    print("Attribute Details:")
    print(df[categorical_features[i]].value_counts())
    print()
# Out:
# Feature Name: workclass
# Attribute Details:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64
#
# Feature Name: education
# Attribute Details:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64
#
# Feature Name: marital-status
# Attribute Details:
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: marital-status, dtype: int64
#
# Feature Name: occupation
# Attribute Details:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64
#
# Feature Name: relationship
# Attribute Details:
#  Husband           13193
#  Not-in-family      8305
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: relationship, dtype: int64
#
# Feature Name: race
# Attribute Details:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64
#
# Feature Name: sex
# Attribute Details:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64
#
# Feature Name: native-country
# Attribute Details:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  Greece                           29
#  France                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Thailand                         18
#  Laos                             18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: native-country, dtype: int64
#
# Feature Name: salary_detail
# Attribute Details:
#  <=50K    24720
#  >50K      7841
# Name: salary_detail, dtype: int64
#
# Feature Name: age_group
# Attribute Details:
# 19-30              9627
# 31-40              8546
# 41-50              6983
# 51-60              4128
# 61-70              1792
# Greater than 70    1485
# Name: age_group, dtype: int64

# %%
df.loc[(df['native-country'] == ' ?') & (df['occupation'] == ' ?')]
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 61      32         ?  293936        7th-8th              4
# 297     39         ?  157443        Masters             14
# 1152    24         ?   35633   Some-college             10
# 1676    64         ?  168340        HS-grad              9
# 2513    47         ?  174525        HS-grad              9
# 3131    25         ?  237865   Some-college             10
# 3579    21         ?  180303      Bachelors             13
# 3834    32         ?  169886      Bachelors             13
# 6059    35         ?  163582           10th              6
# 7862    29         ?  125159   Some-college             10
# 9616    32         ?  647882        HS-grad              9
# 11614   35         ?  103710      Bachelors             13
# 12996   37         ?  122265        HS-grad              9
# 16488   33         ?  119918      Bachelors             13
# 16838   28         ?  149646   Some-college             10
# 18615   27         ?  251854      Bachelors             13
# 20333   69         ?  199591    Prof-school             15
# 20480   55         ?  316027        7th-8th              4
# 23729   41         ?  211873      Assoc-voc             11
# 23915   24         ?  311949        HS-grad              9
# 25359   38         ?   94559      Bachelors             13
# 26296   68         ?  286869        7th-8th              4
# 26363   48         ?  353824   Some-college             10
# 28194   27         ?  133359      Bachelors             13
# 28688   20         ?  200061   Some-college             10
# 30369   20         ?  250037   Some-college             10
# 32525   81         ?  120478      Assoc-voc             11
#
#                marital-status occupation    relationship                 race  \
# 61      Married-spouse-absent          ?   Not-in-family                White
# 297        Married-civ-spouse          ?            Wife   Asian-Pac-Islander
# 1152            Never-married          ?   Not-in-family                White
# 1676       Married-civ-spouse          ?         Husband                White
# 2513       Married-civ-spouse          ?         Husband                White
# 3131            Never-married          ?       Own-child                Black
# 3579            Never-married          ?   Not-in-family   Asian-Pac-Islander
# 3834            Never-married          ?   Not-in-family                White
# 6059                 Divorced          ?       Unmarried                White
# 7862            Never-married          ?   Not-in-family                Black
# 9616       Married-civ-spouse          ?         Husband                White
# 11614                Divorced          ?       Unmarried                White
# 12996                Divorced          ?   Not-in-family   Asian-Pac-Islander
# 16488           Never-married          ?   Not-in-family                Black
# 16838                Divorced          ?       Own-child                White
# 18615      Married-civ-spouse          ?            Wife                Black
# 20333      Married-civ-spouse          ?            Wife                White
# 20480      Married-civ-spouse          ?         Husband                White
# 23729      Married-civ-spouse          ?            Wife                White
# 23915           Never-married          ?   Not-in-family   Asian-Pac-Islander
# 25359      Married-civ-spouse          ?            Wife                Other
# 26296                 Widowed          ?   Not-in-family                White
# 26363      Married-civ-spouse          ?         Husband                White
# 28194   Married-spouse-absent          ?   Not-in-family                White
# 28688           Never-married          ?       Own-child                White
# 30369           Never-married          ?       Own-child                White
# 32525                Divorced          ?       Unmarried                White
#
#            sex  capital-gain  capital-loss  hours-per-week native-country  \
# 61        Male             0             0              40              ?
# 297     Female          3464             0              40              ?
# 1152      Male             0             0              40              ?
# 1676      Male             0             0              40              ?
# 2513      Male          3942             0              40              ?
# 3131      Male             0             0              40              ?
# 3579      Male             0             0              25              ?
# 3834    Female             0             0              20              ?
# 6059    Female             0             0              16              ?
# 7862      Male             0             0              36              ?
# 9616      Male             0             0              40              ?
# 11614   Female             0             0              16              ?
# 12996   Female             0             0              42              ?
# 16488     Male             0             0              45              ?
# 16838   Female             0             0              20              ?
# 18615   Female             0             0              35              ?
# 20333   Female             0             0              25              ?
# 20480     Male             0             0              40              ?
# 23729   Female             0          1628               5              ?
# 23915   Female             0             0              45              ?
# 25359   Female          7688             0              50              ?
# 26296   Female             0          1668              40              ?
# 26363     Male             0             0              40              ?
# 28194     Male             0             0              50              ?
# 28688   Female             0             0              40              ?
# 30369   Female             0             0              18              ?
# 32525   Female             0             0               1              ?
#
#       salary_detail        age_group
# 61            <=50K            31-40
# 297           <=50K            31-40
# 1152          <=50K            19-30
# 1676           >50K            61-70
# 2513          <=50K            41-50
# 3131          <=50K            19-30
# 3579          <=50K            19-30
# 3834          <=50K            31-40
# 6059          <=50K            31-40
# 7862          <=50K            19-30
# 9616          <=50K            31-40
# 11614         <=50K            31-40
# 12996         <=50K            31-40
# 16488         <=50K            31-40
# 16838         <=50K            19-30
# 18615          >50K            19-30
# 20333         <=50K            61-70
# 20480         <=50K            51-60
# 23729         <=50K            41-50
# 23915         <=50K            19-30
# 25359          >50K            31-40
# 26296         <=50K            61-70
# 26363          >50K            41-50
# 28194         <=50K            19-30
# 28688         <=50K            19-30
# 30369         <=50K            19-30
# 32525         <=50K  Greater than 70

# %%
df['occupation'] = df['occupation'].replace([' ?'],'Unavailable')
df['workclass'] = df['workclass'].replace([' ?'],'Unavailable')
df['native-country'] = df['native-country'].replace([' ?'],'Unavailable')
df.loc[(df['native-country'] == 'Unavailable') & (df['occupation'] == 'Unavailable')]
# Out:
#        age    workclass  fnlwgt      education  education-num  \
# 61      32  Unavailable  293936        7th-8th              4
# 297     39  Unavailable  157443        Masters             14
# 1152    24  Unavailable   35633   Some-college             10
# 1676    64  Unavailable  168340        HS-grad              9
# 2513    47  Unavailable  174525        HS-grad              9
# 3131    25  Unavailable  237865   Some-college             10
# 3579    21  Unavailable  180303      Bachelors             13
# 3834    32  Unavailable  169886      Bachelors             13
# 6059    35  Unavailable  163582           10th              6
# 7862    29  Unavailable  125159   Some-college             10
# 9616    32  Unavailable  647882        HS-grad              9
# 11614   35  Unavailable  103710      Bachelors             13
# 12996   37  Unavailable  122265        HS-grad              9
# 16488   33  Unavailable  119918      Bachelors             13
# 16838   28  Unavailable  149646   Some-college             10
# 18615   27  Unavailable  251854      Bachelors             13
# 20333   69  Unavailable  199591    Prof-school             15
# 20480   55  Unavailable  316027        7th-8th              4
# 23729   41  Unavailable  211873      Assoc-voc             11
# 23915   24  Unavailable  311949        HS-grad              9
# 25359   38  Unavailable   94559      Bachelors             13
# 26296   68  Unavailable  286869        7th-8th              4
# 26363   48  Unavailable  353824   Some-college             10
# 28194   27  Unavailable  133359      Bachelors             13
# 28688   20  Unavailable  200061   Some-college             10
# 30369   20  Unavailable  250037   Some-college             10
# 32525   81  Unavailable  120478      Assoc-voc             11
#
#                marital-status   occupation    relationship  \
# 61      Married-spouse-absent  Unavailable   Not-in-family
# 297        Married-civ-spouse  Unavailable            Wife
# 1152            Never-married  Unavailable   Not-in-family
# 1676       Married-civ-spouse  Unavailable         Husband
# 2513       Married-civ-spouse  Unavailable         Husband
# 3131            Never-married  Unavailable       Own-child
# 3579            Never-married  Unavailable   Not-in-family
# 3834            Never-married  Unavailable   Not-in-family
# 6059                 Divorced  Unavailable       Unmarried
# 7862            Never-married  Unavailable   Not-in-family
# 9616       Married-civ-spouse  Unavailable         Husband
# 11614                Divorced  Unavailable       Unmarried
# 12996                Divorced  Unavailable   Not-in-family
# 16488           Never-married  Unavailable   Not-in-family
# 16838                Divorced  Unavailable       Own-child
# 18615      Married-civ-spouse  Unavailable            Wife
# 20333      Married-civ-spouse  Unavailable            Wife
# 20480      Married-civ-spouse  Unavailable         Husband
# 23729      Married-civ-spouse  Unavailable            Wife
# 23915           Never-married  Unavailable   Not-in-family
# 25359      Married-civ-spouse  Unavailable            Wife
# 26296                 Widowed  Unavailable   Not-in-family
# 26363      Married-civ-spouse  Unavailable         Husband
# 28194   Married-spouse-absent  Unavailable   Not-in-family
# 28688           Never-married  Unavailable       Own-child
# 30369           Never-married  Unavailable       Own-child
# 32525                Divorced  Unavailable       Unmarried
#
#                       race      sex  capital-gain  capital-loss  \
# 61                   White     Male             0             0
# 297     Asian-Pac-Islander   Female          3464             0
# 1152                 White     Male             0             0
# 1676                 White     Male             0             0
# 2513                 White     Male          3942             0
# 3131                 Black     Male             0             0
# 3579    Asian-Pac-Islander     Male             0             0
# 3834                 White   Female             0             0
# 6059                 White   Female             0             0
# 7862                 Black     Male             0             0
# 9616                 White     Male             0             0
# 11614                White   Female             0             0
# 12996   Asian-Pac-Islander   Female             0             0
# 16488                Black     Male             0             0
# 16838                White   Female             0             0
# 18615                Black   Female             0             0
# 20333                White   Female             0             0
# 20480                White     Male             0             0
# 23729                White   Female             0          1628
# 23915   Asian-Pac-Islander   Female             0             0
# 25359                Other   Female          7688             0
# 26296                White   Female             0          1668
# 26363                White     Male             0             0
# 28194                White     Male             0             0
# 28688                White   Female             0             0
# 30369                White   Female             0             0
# 32525                White   Female             0             0
#
#        hours-per-week native-country salary_detail        age_group
# 61                 40    Unavailable         <=50K            31-40
# 297                40    Unavailable         <=50K            31-40
# 1152               40    Unavailable         <=50K            19-30
# 1676               40    Unavailable          >50K            61-70
# 2513               40    Unavailable         <=50K            41-50
# 3131               40    Unavailable         <=50K            19-30
# 3579               25    Unavailable         <=50K            19-30
# 3834               20    Unavailable         <=50K            31-40
# 6059               16    Unavailable         <=50K            31-40
# 7862               36    Unavailable         <=50K            19-30
# 9616               40    Unavailable         <=50K            31-40
# 11614              16    Unavailable         <=50K            31-40
# 12996              42    Unavailable         <=50K            31-40
# 16488              45    Unavailable         <=50K            31-40
# 16838              20    Unavailable         <=50K            19-30
# 18615              35    Unavailable          >50K            19-30
# 20333              25    Unavailable         <=50K            61-70
# 20480              40    Unavailable         <=50K            51-60
# 23729               5    Unavailable         <=50K            41-50
# 23915              45    Unavailable         <=50K            19-30
# 25359              50    Unavailable          >50K            31-40
# 26296              40    Unavailable         <=50K            61-70
# 26363              40    Unavailable          >50K            41-50
# 28194              50    Unavailable         <=50K            19-30
# 28688              40    Unavailable         <=50K            19-30
# 30369              18    Unavailable         <=50K            19-30
# 32525               1    Unavailable         <=50K  Greater than 70

# %%
sns.boxplot(x='age', data=df)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# Scaling?

# %% [markdown]
# Gathering insights from the data by graphically exploring different attributes from the dataset

# %%
# Bivariate analysis

# %%
sns.set_style("whitegrid")
plt.figure(figsize = (8,5))
plt.title('Income Distribution of Adults', fontsize=18, fontweight='bold')
eda_percentage = df['salary_detail'].value_counts(normalize = True).rename_axis('salary_detail').reset_index(name = 'Percentage')

ax = sns.barplot(x = 'salary_detail', y = 'Percentage', data = eda_percentage.head(10), palette='rocket_r')
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.0%}', (x + width/2, y + height*1.02), ha='center', fontweight='bold')

# %%
def age_group(x):
    x = int(x)
    x = abs(x)
    if( 18 < x < 31 ):
        return "19-30"
    if( 30 < x < 41 ):
        return "31-40"
    if( 40 < x < 51 ):
        return "41-50"
    if( 50 < x < 61 ):
        return "51-60"
    if( 60 < x < 71 ):
        return "61-70"
    else:
        return "Greater than 70"

df['age_group'] = df['age'].apply(age_group)

# %%
plt.figure(figsize=(12,6))
order_list = ['19-30', '31-40', '41-50', '51-60', '61-70', 'Greater than 70']
sns.countplot(df['age_group'], hue = df['salary_detail'], palette='rocket_r', order = order_list)
plt.title('Income of Individuals of Different Age Groups', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
# Out:
# C:\Users\drish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
#order_list = ['19-30', '31-40', '41-50', '51-60', '61-70', 'Greater than 70']
sns.countplot(df['workclass'], hue = df['salary_detail'], palette='rocket_r')
plt.title('Income of Individuals of Different Working CLasses', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16,rotation = 90)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
# Out:
# C:\Users\drish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(15,6))
# #order_list = ['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th', '10th', '11th', '12th', 
#                 'HS-grad ', 'Some-college', 'Bachelors', 'Masters', 'Doctorate', 'Prof-school', 
#               'Assoc-acdm', 'Assoc-voc']
sns.countplot(df['education'], hue = df['salary_detail'], palette='rocket_r')
plt.title('Income of Individuals of Different Education Levels', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16,rotation = 90)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
# Out:
# C:\Users\drish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(18,6))
#order_list = ['19-30', '31-40', '41-50', '51-60', '61-70', 'Greater than 70']
sns.countplot(df['occupation'], hue = df['salary_detail'], palette='rocket_r')
plt.title('Income of Individuals of Different Occupations', fontsize=18, fontweight='bold')
plt.xticks(fontsize=16,rotation = 90)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)
# Out:
# C:\Users\drish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
